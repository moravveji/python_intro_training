# %% [markdown]
# # Built-in data types

# %%
# In order to ensure that all cells in this notebook can be evaluated without errors, we will use try-except to catch exceptions. To show the actual errors, we need to print the backtrace, hence the following import.
from traceback import print_exc

# %% [markdown]
# ## Key concepts in programming
#
# - Variables (integers, strings, dates, etc.)
# - Flow control (if then, loop, etc.)
# - Functions (list of steps the code will follow)

# %% [markdown]
# ## built-in data types
#
# | Type | Meaning | Example |
# |------|---------|---------|
# | int | integers (whole numbers) | a = 2 |
# | float | floating point numbers (real numbers) | a = 2.0 |
# | complex | complex numbers with a real and imaginary part | a = 1.2 + 3j |
# | bool | boolean: True/False values | a = True |
# | str | string: characters or text | a = 'abc' |

# %% [markdown]
# ## integer
# - Most basic numerical type.
# - Any number without a decimal point is an integer.
# - Note: Python integers are variable-precision, not limited as in C, Matlab to 4 or 8 bytes.
#     - see https://rushter.com/blog/python-integer-implementation/

# %%
a = 2
b = 2**200
print('type of a', type(a))
print('type of b', type(b))
print('a: ', a)
print('b: ', b)
print('size of a:', a.__sizeof__(), ' bits')
print('size of b:', b.__sizeof__(), ' bits')
# Out:
# type of a <class 'int'>
# type of b <class 'int'>
# a:  2
# b:  1606938044258990275541962092341162602522202993782792835301376
# size of a: 16  bits
# size of b: 40  bits

# %% [markdown]
# ## floating point
#
# - The floating-point type can store fractional numbers.
# - standard decimal notation, or in exponential notation
#   * ´a = 0.000005´
#   * ´b = 5e-6´
#  - Note:  limited precision, never rely on exact equality tests with floating-point values.
# 0.1 + 0.2 == 0.3

# %%
a = 0.000005
b = 5.08e-6
print(a, b)
print('type', type(a))
print('type', type(b))
# Out:
# 5e-06 5.08e-06
# type <class 'float'>
# type <class 'float'>

# %% [markdown]
# comparisons with float numbers can be tricky
#
# due to the limited precision of representing floats, never rely on exact equality tests with floating-point values. 0.1 + 0.2 == 0.3

# %%
a = 0.1
b = 0.2
print('a + b =', a + b)
c = 0.3
print('test a + b == c: ', (a + b) == c)
# Out:
# a + b = 0.30000000000000004
# test a + b == c:  False

# %% [markdown]
# A better way to cmpare floats: check the absolute difference

# %%
epsilon = 0.00001
x = 0.1 + 0.2
y = 0.3
print(abs(x - y) < epsilon)
# Out:
# True

# %% [markdown]
# get an idea of the binary representation of a float: you can convert the float to an integer using the int.from_bytes() function, and then convert that integer to binary with the bin() function.

# %%
import struct

x = 0.1
print(x.hex())
packed = struct.pack('f', x)
integer = int.from_bytes(packed, byteorder='big')
binary = bin(integer)
print(binary)
y = x

# precision needed beyond 16th digit!
x = 0.10000000000000001
print(x.hex())
packed = struct.pack('f', x)
integer = int.from_bytes(packed, byteorder='big')
binary = bin(integer)
print(binary)

print(x==y)
# Out:
# 0x1.999999999999ap-4
# 0b11001101110011001100110000111101
# 0x1.999999999999ap-4
# 0b11001101110011001100110000111101
# True

# %% [markdown]
# In the context of programming and numerical computation, “machine epsilon” refers to the smallest representable number such that 1.0 + epsilon is not equal to 1.0. It represents the upper bound on the relative error due to rounding in floating point arithmetic.
#
# Machine epsilon is a measure of precision in the representation of real numbers in a computer. It varies between systems and is specific to the floating-point format used by the system.

# %%
import sys
epsilon = sys.float_info.epsilon
print(epsilon)
# Out:
# 2.220446049250313e-16

# %% [markdown]
# ## complex
# - A complex number consists of 2 doubles
# - It accepts either `J` or `j` but the numerical value of the imaginary part must immediately precede it. If the imaginary part is a variable the 1 must be present.

# %%
a = 7.86
c1 = complex(1, 2)
c2 = 3 + 5.3j
print('type: ', type(c1))
print('dir: ', dir(c1))
c1.imag
c1.real
c3 = 2.3 + a*1j
#c3 = 2.3 + a*j

# %% [markdown]
# ## boolean
# - Simple type with two possible values: True and False

# %%
result = (4 > 5)
print('result: ', result)
print('type: ', type(result))

# %%
a = 2.3
b = 3.4
c = bool(a*b)
print(c)
d = bool(0*a)
print(d)

# %% [markdown]
# ## type conversion
# If a variable is of one type but it needs to be of a different type, it is necessary to do a type conversion aka a cast.

# %%
i = 6
r = float(i)
print('r: ', r)
ii = int(3.14)
print('ii: ', ii)
z = complex(1.2, 3.4)
print('z: ', z)
s = str(r)
print('type s: ', type(s))
print('s: ', s)
z = s + 1
# Out:
# r:  6.0
# ii:  3
# z:  (1.2+3.4j)
# type s:  <class 'str'>
# s:  6.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 11
#       9 print('type s: ', type(s))
#      10 print('s: ', s)
# ---> 11 z = s + 1
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ## string
#
# (some inspiration from http://www.cs.cornell.edu/courses/cs1110/2019fa/lectures/lecture5/presentation-05.pdf)
#
# - A string is a (ordered) sequence of characters
# - Created with single ‘ or double quotes “
#     - 'ab cd' (' preferred)
#     - "ab cd"
#     - slicing
# - immutable: cannot be changed

# %%
#   '012345678901'
s = 'Hello World!'
print(s)
print(id(s))
print('s[0] ', s[0])
print('s[2:] ', s[2:])
print('s[2:4] ', s[2:4])
print('s[2:8:1] ', s[2:8:1])
print('s[2:8:2] ', s[2:8:2])

# assign a new value
s = 'Where are you?'
print(s)
print(id(s))
s[7] = 'x'
# Out:
# Hello World!
# 69047032
# s[0]  H
# s[2:]  llo World!
# s[2:4]  ll
# s[2:8:1]  llo Wo
# s[2:8:2]  loW
# Where are you?
# 73501672
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 15
#      13 print(s)
#      14 print(id(s))
# ---> 15 s[7] = 'x'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ### string concatenation and replication
#
# concatenation of string variables or constants using the + operator
#
# replication: multiply a string by a number

# %%
a = 'John'
b = 'Mary'
c = a + b
print(c)
c_bis = a + ' ' + b
print(c_bis)

# add a number
d = a + str(4.5)
print(d)
e = a*4+b*2
print(e)
# Out:
# JohnMary
# John Mary
# John4.5
# JohnJohnJohnJohnMaryMary

# %% [markdown]
# ### strings and Methods
#
# `rstrip`
#
# - Getting rid of line endings: `rstrip('\r\n')`
# - Method will strip all combinations of \r and \n from right end of string
# - Similar methods:
#    - `lstrip`: strips from left end of string
#    - `strip`: strips from both ends of string
# - No arguments, strips: space, \t, \r, \n, …
# - These methods do not modify the original string, instead they return a new string that has been altered

# %%
str1 = 'this is a string'
print(dir(str1))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
str1.capitalize()
# Out:
# 'This is a string'

# %%
my_str_1 = 'this is my string,\t with some text in it \n More text on a next line \n'
dir(my_str_1)
print(my_str_1)
print(my_str_1.rstrip())
# Out:
# this is my string,	 with some text in it
#  More text on a next line
#
# this is my string,	 with some text in it
#  More text on a next line

# %% [markdown]
# `split`
#
# Splitting string: `split()` returns list of strings
# - no argument: split on (multiple) whitespace
# - otherwise, split on provided string
# - limit number of splits by providing extra argument

# %%
my_str_1 = 'this is my string,\t with some text in it \n More text on a next line \n'
print(my_str_1)
my_str_split_1 = my_str_1.split()
print(my_str_split_1)
my_str_split_2 = my_str_1.split(',')
print(my_str_split_2)

my_str_3 = 'end 1: 2013-03-28 03:05:57'
# split on :, but keep the time format!
my_str_split_3 = my_str_3.split(':', 1)
print(my_str_split_3)
# Out:
# this is my string,	 with some text in it
#  More text on a next line
#
# ['this', 'is', 'my', 'string,', 'with', 'some', 'text', 'in', 'it', 'More', 'text', 'on', 'a', 'next', 'line']
# ['this is my string', '\t with some text in it \n More text on a next line \n']
# ['end 1', ' 2013-03-28 03:05:57']

# %%
my_long_string = ' this is a nice piece of text for you   '
my_words = my_long_string.split()
print(my_words)

# split on a specified character
my_words_bis = my_long_string.split('i')
print(my_words_bis)

#%% putting things together
new_word = ' '.join(my_words_bis).strip()
print(new_word)
# Out:
# ['this', 'is', 'a', 'nice', 'piece', 'of', 'text', 'for', 'you']
# [' th', 's ', 's a n', 'ce p', 'ece of text for you   ']
# th s  s a n ce p ece of text for you

# %% [markdown]
# More methods: is<something>
#     isupper
#     islower
#     isspace
#     isdigit
#     isalpha

# %%
print('ABC'.isupper())
print('A19'.isupper())
print('Abc'.isupper())
print('19'.isupper())
my_str_1 = 'this is my string,\t with some text in it \n More text on a next line \n'
print(my_str_1.isalpha())
print(my_str_1.isalnum())
# Out:
# True
# True
# False
# False
# False
# False

# %% [markdown]
# ### searching and replacing
#
# - does a string contain a substring: `in`
#
# - search: `index` or `find`
#     - find returns -1 when the substring is not found
#         - only for strings
#     - index will return an error
#         - also for lists and tuples
# - Function `len()` computes str length
# - replace with `replace`
#
# Make combinations
# - cut to pull out parts
# - glue to create new strings

# %%
# substring in string
print('ab' in 'ABCD')
print('ab' in 'ABCDab')
# Out:
# False
# True

# %%
# extract information between braces
str1 = ' this is a string containing (some) text'
# find the first occurence of '('
start_brc = str1.index('(')
# cut from the first brace
tail = str1[start_brc+1:]
# find the first occurence of ')'
end_brc = tail.index(')')
text = tail[:end_brc]
print('extracted text: ', text)
print('len(str1) :', len(str1))
print(str1.replace('is', 'as'))
str1 = str1.replace('is', 'was')
print(str1)
# Out:
# extracted text:  some
# len(str1) : 40
#  thas as a string containing (some) text
#  thwas was a string containing (some) text

# %%
#   '012345678901'
s = 'Hello World!'
print('s[0] ', s[0])
print('s[2:] ', s[2:])
print('s[2:4] ', s[2:4])
print('s[2:8:1] ', s[2:8:1])
print('s[2:8:2] ', s[2:8:2])
print('s[:4] ', s[:4])

print('s[:] ', s[:])
print('s[-1] ', s[-1])
print('s[8:4:-1] ', s[8:4:-1])
print('s[:4:-1] ', s[:4:-1])
print('s[8::-1] ', s[8::-1])
print('s[::-1] ', s[::-1])
# Out:
# s[0]  H
# s[2:]  llo World!
# s[2:4]  ll
# s[2:8:1]  llo Wo
# s[2:8:2]  loW
# s[:4]  Hell
# s[:]  Hello World!
# s[-1]  !
# s[8:4:-1]  roW
# s[:4:-1]  !dlroW
# s[8::-1]  roW olleH
# s[::-1]  !dlroW olleH

# %%
small_str_1 = ' small'
small_str_2 = ' part'
concat_1 = small_str_1 + small_str_2
print('concat_1: ', concat_1)
concat_2 = 3*small_str_1
print('concat_2: ', concat_2)
# Out:
# concat_1:   small part
# concat_2:   small small small

# %%
str1 = 'help'
str2 = 'me'
a1 = str1 + str2
print(a1)
# Out:
# helpme

# %%
print(str1*3)
# Out:
# helphelphelp

# %% [markdown]
# ## format output
#
# ### printf-style formatting:
# This is similar to the formatting used in C’s printf function. It’s less commonly used in modern Python code.
#
# ### str.format():
# This method is more versatile and can be used in Python 2.7 and above.
#
# ### string Interpolation (f-strings):
# Available since Python 3.6
# F-string is a string literal that is prefixed with `f` or `F`. These strings may contain replacement fields (delimited by curly braces {} – fill out the braces). F-string is evaluated at run time.
#
# File: fstring_01.py

# %%
name = 'Peter'
age = 23

print('%s is %d years old' % (name, age))       # printf style
print('{} is {} years old'.format(name, age))   # .format
print(f'{name} is {age} years old')             # f-string

# %%
fnum = 2007.12345
print(f"Simple = {fnum}")
print(f"Decimal Places specified = {fnum:.2f}")
print(f"Significant Figures={fnum:.3g}")
# Out:
# Simple = 2007.12345
# Decimal Places specified = 2007.12
# Significant Figures=2.01e+03

# %% [markdown]
# ## character
#
# `ord()` takes a string argument of a single Unicode character and returns its integer Unicode code point value.
#
# `chr()` function takes integer argument and returns the string representing a character.

# %%
print(ord('a'))

print(chr(98))

# %% [markdown]
# ## docstring
#
# Documentation strings or “docstrings” use a special form of comment.
# The lines are enclosed in triple double quotes
# """  """
# - Everything within triple double quotes is treated as a literal string and a comment, including line breaks.
# - Docstrings are placed at the top of program units, just under the declaration of the unit name (if present).
# - If they are correctly placed, certain automated tools are available to display the documentation.

# %% [markdown]
# ### None
#
# `None` is the equivalent of null in C.
#
# When to use? Often you want to perform an action that may or may not work. Using `None` is one way you can check the state of the action later.

# %%
a=None
print(id(a))
print(type(a))

r_v = print('abc')
print(r_v)
